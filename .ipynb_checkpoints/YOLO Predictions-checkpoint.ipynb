# %% [markdown]
# ## Importing Libraries

# %%
import cv2
import numpy as np
import os
import pytesseract as pt
import matplotlib.pyplot as plt

# %%
pt.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
# !pip install pytesseract
# !pip install tesseract
# !pip install tesseract-ocr

# %%
# settings 
INPUT_WIDTH = 640
INPUT_HEIGHT = 640

# %% [markdown]
# ## Loading the image to be detected

# %%
img = cv2.imread("./Verification/3.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 799.5, 599.5, -0.5)

# %% [markdown]
# ## Loading the trained YOLOv5 model

# %%
net = cv2.dnn.readNetFromONNX("./Model-YOLOv5-Collab/Model/weights/best.onnx")
net.setPreferableBackend(cv2.dnn.DNN_BACKEND_OPENCV)
net.setPreferableTarget(cv2.dnn.DNN_TARGET_CPU)

# %% [markdown]
# ## Converting image to YOLO Format generating the predictions

# %%
image = img.copy()
row, col, d = image.shape

max_rc = max(row, col)
input_image = np.zeros((max_rc, max_rc, 3), dtype=np.uint8)
input_image[0:row, 0:col] = image
plt.imshow(input_image)
plt.axis("off")
# Out:
# (-0.5, 799.5, 799.5, -0.5)

# %%
blob = cv2.dnn.blobFromImage(input_image, 1/255, (INPUT_WIDTH, INPUT_HEIGHT), swapRB=True, crop=False)
net.setInput(blob)
preds = net.forward()
detections = preds[0]

# %%
detections.shape
# Out:
# (25200, 6)

# %% [markdown]
# ## Filtering the detection based on the confidence and probability scores

# %%
boxes = []
confidences = []

image_w, image_h = input_image.shape[:2]
x_factor = image_w / INPUT_WIDTH
y_factor = image_h / INPUT_HEIGHT

for i in range(len(detections)):
    row = detections[i]
    confidence = row[4]
    if confidence > 0.4:
        class_score = row[5]
        if class_score > 0.25:
            cx, cy, w, h = row[0:4]
            
            left = int((cx - 0.5 * w) * x_factor)
            top = int((cy - 0.5 * h) * y_factor)
            width = int(w * x_factor)
            height = int(h * y_factor)
            box = np.array([left,top,width,height])
            
            confidences.append(confidence)
            boxes.append(box)

# %%
boxes[:5]
# Out:
# [array([ 96, 328, 148,  40]),
#  array([ 97, 328, 147,  39]),
#  array([101, 327, 139,  40]),
#  array([101, 327, 140,  39]),
#  array([104, 328, 137,  39])]

# %%
# Clean
boxes_np = np.array(boxes).tolist()
confidences_np = np.array(confidences).tolist()

# %%
boxes_np[:5]
# Out:
# [[96, 328, 148, 40],
#  [97, 328, 147, 39],
#  [101, 327, 139, 40],
#  [101, 327, 140, 39],
#  [104, 328, 137, 39]]

# %%
confidences_np[:5]
# Out:
# [0.8690118789672852,
#  0.6708756685256958,
#  0.49517178535461426,
#  0.5733199119567871,
#  0.47358638048171997]

# %%
index = cv2.dnn.NMSBoxes(boxes_np, confidences_np, 0.25, 0.45).flatten()

# %%
index
# Out:
# array([6])

# %% [markdown]
# ## Drawing the detected bounding box

# %%
for ind in index:
    print("ran")
    x,y,w,h = boxes_np[ind]
    bb_conf = confidences_np[ind]
    conf_text = "plate {:.0f}%".format(bb_conf*100)

    
    cv2.rectangle(image, (x,y), (x+w, y+h), (255,0,255), 10)
    cv2.rectangle(image, (x,y-30), (x+w, y), (0, 0, 0),-1)
    
    cv2.putText(image, conf_text, (x,y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255,255,255),3)
    
plt.imshow(image)
plt.axis("off")
# Out:
# ran
# (-0.5, 799.5, 599.5, -0.5)

# %% [markdown]
# ## Creating seperate functions for what we did above so that we can use them in the backend of our app

# %%
def get_detections(img, net):
    image = img.copy()
    row, col, d = image.shape

    max_rc = max(row, col)
    input_image = np.zeros((max_rc, max_rc, 3), dtype=np.uint8)
    input_image[0:row, 0:col] = image
    
    blob = cv2.dnn.blobFromImage(input_image, 1/255, (INPUT_WIDTH, INPUT_HEIGHT), swapRB=True, crop=False)
    net.setInput(blob)
    preds = net.forward()
    detections = preds[0]
    
    return input_image, detections

# %%
def non_maximum_supression(input_image, detections):
    boxes = []
    confidences = []

    image_w, image_h = input_image.shape[:2]
    x_factor = image_w / INPUT_WIDTH
    y_factor = image_h / INPUT_HEIGHT

    for i in range(len(detections)):
        row = detections[i]
        confidence = row[4]
        if confidence > 0.4:
            class_score = row[5]
            if class_score > 0.25:
                cx, cy, w, h = row[0:4]

                left = int((cx - 0.5 * w) * x_factor)
                top = int((cy - 0.5 * h) * y_factor)
                width = int(w * x_factor)
                height = int(h * y_factor)
                box = np.array([left,top,width,height])

                confidences.append(confidence)
                boxes.append(box)

    boxes_np = np.array(boxes).tolist()
    confidences_np = np.array(confidences).tolist()
    
    index = cv2.dnn.NMSBoxes(boxes_np, confidences_np, 0.25, 0.45).flatten()
    
    return boxes_np, confidences_np, index

# %%
def drawings(image, boxes_np, confidences_np, index):
    for ind in index:
        x,y,w,h = boxes_np[ind]
        bb_conf = confidences_np[ind]
        conf_text = "plate {:.0f}%".format(bb_conf*100)


        cv2.rectangle(image, (x,y), (x+w, y+h), (255,0,255), 10)
        cv2.rectangle(image, (x,y-30), (x+w, y), (0, 0, 0),-1)

        cv2.putText(image, conf_text, (x,y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255,255,255),3)
        
    return image

# %% [markdown]
# ### Predictions

# %%
def yolo_predictions(img, net):

    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    input_image, detections = get_detections(img, net)

    boxes_np, confidences_np, index = non_maximum_supression(input_image, detections)

    result_img = drawings(img, boxes_np, confidences_np, index)
    
    return result_img

# %% [markdown]
# ### TEST

# %%
img = cv2.imread("./Verification/3.jpg")

# %%
results = yolo_predictions(img, net)
plt.imshow(results)
plt.axis("off")
# Out:
# (-0.5, 799.5, 599.5, -0.5)

# %% [markdown]
# ## Text Extraction

# %%
def extract_text(image,bbox):
    x,y,w,h = bbox
    
    roi = image[y:y+h, x:x+w]
    if 0 in roi.shape:
        return ''
    else:
        roi_bgr = cv2.cvtColor(roi,cv2.COLOR_RGB2BGR)
        resize_img = cv2.resize(roi_bgr, None, fx = 2, fy = 2, interpolation = cv2.INTER_CUBIC)
        gray = cv2.cvtColor(resize_img,cv2.COLOR_BGR2GRAY)
        gaussian_blur_img = cv2.GaussianBlur(gray, (5, 5), 0)

        # text = pt.image_to_string(magic_color,lang='eng',config='--psm 6')
        text = pt.image_to_string(gaussian_blur_img, lang ='eng',
                config ='--oem 3 --psm 7 -c tessedit_char_whitelist=ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789')
        text = text.strip()
        
        return text

# %%
def drawings(image, boxes_np, confidences_np, index):
    for ind in index:
        x,y,w,h = boxes_np[ind]
        bb_conf = confidences_np[ind]
        conf_text = "plate {:.0f}%".format(bb_conf*100)
        
        license_text = extract_text(image, boxes_np[ind])

        cv2.rectangle(image, (x,y), (x+w, y+h), (255,0,255), 10)
        cv2.rectangle(image, (x,y-30), (x+w, y), (0,0,0),-1)
        
        cv2.rectangle(image, (x,y+h), (x+w, y+h+30), (0,0,0),-1)

        cv2.putText(image, conf_text, (x,y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255,255,255),3)
        
        cv2.putText(image, license_text, (x, y+h+25), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255),2)
        
    return image, license_text

# %%
def yolo_predictions(img, net):

#     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    input_image, detections = get_detections(img, net)

    boxes_np, confidences_np, index = non_maximum_supression(input_image, detections)

    result_img, license_text = drawings(img, boxes_np, confidences_np, index)
    
    return result_img, license_text

# %%
img = cv2.imread("./Verification/3.jpg")

result_img, license_text = yolo_predictions(img, net)

# %%
plt.imshow(result_img)
plt.axis("off")
# Out:
# (-0.5, 799.5, 599.5, -0.5)

# %%
print("Lisence Plate Number: " + license_text)
# Out:
# Lisence Plate Number: TN21AT0480
